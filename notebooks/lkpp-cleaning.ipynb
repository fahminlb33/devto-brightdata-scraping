# %%
import itertools

import numpy as np
import pandas as pd

# %% [markdown]
# ## Helpers

# %%
def string_replace_ruleset(ruleset: dict[str, str] = {}):
    def inner_func(s) -> str:
        if s is None or s is np.nan or s == "" or s == "-":
            return np.nan

        for replace_with, find_what in ruleset.items():
            for substring in find_what:
                if substring.lower() in s.lower():
                    return replace_with

        return s.strip()

    return inner_func

# %% [markdown]
# ## SERP Dataset

# %%
df_serp = pd.read_json("../data/scrape-browser/lkpp-serp.jsonl", lines=True)
df_serp.head()
# Out:
#                                                 name  \
# 0              Laptop Administrasi Perkantoran Axioo
# 1  ACER Laptop Travelmate P214 Core i5/8 GB/512 G...
# 2  ACER Laptop Travelmate P214 Core i3/8 GB/512 G...
# 3          AXIOO Laptop Mybook Pro  Core i5 L5 (8N5)
# 4                            AXIOO LAPTOP MYBOOK 14F
#
#                                                 tags  \
# 0  [Produk Dalam Negeri, Verified Vendor, UMKK, N...
# 1  [Produk Dalam Negeri, Verified Vendor, UMKK, N...
# 2  [Produk Dalam Negeri, Verified Vendor, UMKK, N...
# 3  [Produk Dalam Negeri, Verified Vendor, UMKK, N...
# 4  [Produk Dalam Negeri, Verified Vendor, UMKK, N...
#
#                                              details  page  category  \
# 0  {'provider': 'CAESAR SAPTA PRATAMA', 'tkdn_per...     1   1237626
# 1  {'provider': 'Cemerlang Air Cond', 'tkdn_perce...     1   1237626
# 2  {'provider': 'Cemerlang Air Cond', 'tkdn_perce...     1   1237626
# 3  {'provider': 'Cemerlang Air Cond', 'tkdn_perce...     1   1237626
# 4  {'provider': 'PT STATION SUMBER MAKMUR JAYA', ...     1   1237626
#
#    commodity                                        product_url  \
# 0      90424  https://e-katalog.lkpp.go.id/katalog/produk/de...
# 1      90424  https://e-katalog.lkpp.go.id/katalog/produk/de...
# 2      90424  https://e-katalog.lkpp.go.id/katalog/produk/de...
# 3      90424  https://e-katalog.lkpp.go.id/katalog/produk/de...
# 4      90424  https://e-katalog.lkpp.go.id/katalog/produk/de...
#
#                                            image_url  \
# 0  https://e-katalog.lkpp.go.id/katalog/produk/do...
# 1  https://e-katalog.lkpp.go.id/katalog/produk/do...
# 2  https://e-katalog.lkpp.go.id/katalog/produk/do...
# 3  https://e-katalog.lkpp.go.id/katalog/produk/do...
# 4  https://e-katalog.lkpp.go.id/katalog/produk/do...
#
#                                           scrape_url
# 0  https://e-katalog.lkpp.go.id/productsearchcont...
# 1  https://e-katalog.lkpp.go.id/productsearchcont...
# 2  https://e-katalog.lkpp.go.id/productsearchcont...
# 3  https://e-katalog.lkpp.go.id/productsearchcont...
# 4  https://e-katalog.lkpp.go.id/productsearchcont...

# %%
# derive ID from URL
df_serp["id"] = df_serp["product_url"].str.extract(r"\/(\d+)\?")

# %%
# one-hot encode tags
product_tags = list(set(itertools.chain(*df_serp["tags"].tolist())) - set([None]))
product_tags_cols = ["tag_" + x.lower().replace(" ", "_") for x in product_tags]

df_serp[product_tags_cols] = df_serp.apply(lambda x: [True if v in x["tags"] else False for v in product_tags], axis=1, result_type='expand')

# %%
# drop unnecessary columns
df_product_tags = df_serp[["id", *product_tags_cols]]
df_product_tags.head()
# Out:
#          id  tag_umkk  tag_verified_vendor  tag_official_vendor  \
# 0  83451581      True                 True                False
# 1  84521755      True                 True                False
# 2  84521452      True                 True                False
# 3  83971989      True                 True                False
# 4  80375727      True                 True                False
#
#    tag_produk_dalam_negeri
# 0                     True
# 1                     True
# 2                     True
# 3                     True
# 4                     True

# %% [markdown]
# ## Product Detail Dataset

# %%
df = pd.read_json("../data/scrape-browser/lkpp-products.jsonl", lines=True)
df.head()
# Out:
#                                                title  \
# 0              LAPTOP ADMINISTRASI PERKANTORAN AXIOO
# 1  ACER LAPTOP TRAVELMATE P214 CORE I5/8 GB/512 G...
# 2  ACER LAPTOP TRAVELMATE P214 CORE I3/8 GB/512 G...
# 3           AXIOO LAPTOP MYBOOK PRO CORE I5 L5 (8N5)
# 4                            AXIOO LAPTOP MYBOOK 14F
#
#                         sku             price                stock  \
# 0  4522100001-LTN-224654966  Rp 12.500.000,00    Stok Produk :   5
# 1  4522100001-LTN-230428659  Rp 18.300.000,00  Stok Produk :   312
# 2  4522100001-LTN-230427140  Rp 15.070.000,00  Stok Produk :   312
# 3  4522100001-LTN-227419165  Rp 18.100.000,00  Stok Produk :   211
# 4  4522100001-LTN-208199795   Rp 3.999.000,00    Stok Produk :   1
#
#                                                 tags  \
# 0  [CAESAR SAPTA PRATAMA, Katalog Nasional, Peral...
# 1  [Cemerlang Air Cond, Katalog Nasional, Peralat...
# 2  [Cemerlang Air Cond, Katalog Nasional, Peralat...
# 3  [Cemerlang Air Cond, Katalog Nasional, Peralat...
# 4  [PT STATION SUMBER MAKMUR JAYA, Katalog Nasion...
#
#                                              details  \
# 0  {'Nama Produk': 'Laptop Administrasi Perkantor...
# 1  {'Nama Produk': 'Laptop Travelmate P214 Core i...
# 2  {'Nama Produk': 'Laptop Travelmate P214 Core i...
# 3  {'Nama Produk': 'Laptop Mybook Pro Core i5 L5 ...
# 4  {'Nama Produk': 'LAPTOP MYBOOK 14F', 'Masa Ber...
#
#                                                  url  \
# 0  https://e-katalog.lkpp.go.id/katalog/produk/de...
# 1  https://e-katalog.lkpp.go.id/katalog/produk/de...
# 2  https://e-katalog.lkpp.go.id/katalog/produk/de...
# 3  https://e-katalog.lkpp.go.id/katalog/produk/de...
# 4  https://e-katalog.lkpp.go.id/katalog/produk/de...
#
#                                               alerts
# 0  Produk ini Tidak Aktif dan sedang dilaporkan m...
# 1                                                NaN
# 2                                                NaN
# 3  Produk ini Tidak Aktif dan sedang dilaporkan m...
# 4  Produk ini Tidak Aktif dan sedang dilaporkan m...

# %%
df = df.join(pd.json_normalize(df["details"]))
df.head()
# Out:
#                                                title  \
# 0              LAPTOP ADMINISTRASI PERKANTORAN AXIOO
# 1  ACER LAPTOP TRAVELMATE P214 CORE I5/8 GB/512 G...
# 2  ACER LAPTOP TRAVELMATE P214 CORE I3/8 GB/512 G...
# 3           AXIOO LAPTOP MYBOOK PRO CORE I5 L5 (8N5)
# 4                            AXIOO LAPTOP MYBOOK 14F
#
#                         sku             price                stock  \
# 0  4522100001-LTN-224654966  Rp 12.500.000,00    Stok Produk :   5
# 1  4522100001-LTN-230428659  Rp 18.300.000,00  Stok Produk :   312
# 2  4522100001-LTN-230427140  Rp 15.070.000,00  Stok Produk :   312
# 3  4522100001-LTN-227419165  Rp 18.100.000,00  Stok Produk :   211
# 4  4522100001-LTN-208199795   Rp 3.999.000,00    Stok Produk :   1
#
#                                                 tags  \
# 0  [CAESAR SAPTA PRATAMA, Katalog Nasional, Peral...
# 1  [Cemerlang Air Cond, Katalog Nasional, Peralat...
# 2  [Cemerlang Air Cond, Katalog Nasional, Peralat...
# 3  [Cemerlang Air Cond, Katalog Nasional, Peralat...
# 4  [PT STATION SUMBER MAKMUR JAYA, Katalog Nasion...
#
#                                              details  \
# 0  {'Nama Produk': 'Laptop Administrasi Perkantor...
# 1  {'Nama Produk': 'Laptop Travelmate P214 Core i...
# 2  {'Nama Produk': 'Laptop Travelmate P214 Core i...
# 3  {'Nama Produk': 'Laptop Mybook Pro Core i5 L5 ...
# 4  {'Nama Produk': 'LAPTOP MYBOOK 14F', 'Masa Ber...
#
#                                                  url  \
# 0  https://e-katalog.lkpp.go.id/katalog/produk/de...
# 1  https://e-katalog.lkpp.go.id/katalog/produk/de...
# 2  https://e-katalog.lkpp.go.id/katalog/produk/de...
# 3  https://e-katalog.lkpp.go.id/katalog/produk/de...
# 4  https://e-katalog.lkpp.go.id/katalog/produk/de...
#
#                                               alerts  \
# 0  Produk ini Tidak Aktif dan sedang dilaporkan m...
# 1                                                NaN
# 2                                                NaN
# 3  Produk ini Tidak Aktif dan sedang dilaporkan m...
# 4  Produk ini Tidak Aktif dan sedang dilaporkan m...
#
#                                          Nama Produk Masa Berlaku Produk  ...  \
# 0              Laptop Administrasi Perkantoran Axioo          2024-12-31  ...
# 1  Laptop Travelmate P214 Core i5/8 GB/512 GB (TM...          2025-12-31  ...
# 2  Laptop Travelmate P214 Core i3/8 GB/512 GB (TM...          2025-12-31  ...
# 3                 Laptop Mybook Pro Core i5 L5 (8N5)          2025-12-31  ...
# 4                                  LAPTOP MYBOOK 14F          2025-12-31  ...
#
#          RAM      Storage                            VGA  \
# 0       8 Gb       512 Gb        Intel Iris Plus Graphic
# 1  8 GB DDR4    512GB SSD            Integrated Graphics
# 2   8GB DDR4    512GB SSD                 Intel Graphics
# 3  8 GB NVME  512 GB NVME                     Integrated
# 4        6GB    256GB SSD  Integrated Intel UHD Graphics
#
#                    Ukuran Layar                                  Koneksi  \
# 0                       14 inci  Realtek 8821CE ac/b/g/n & Bluetooth 5.0
# 1                       14 inch                     LAN, WiFi, Bluetooth
# 2                       14 Inch                     LAN, WiFi, Bluetooth
# 3                       14 Inch             Koneksi LAN, WiFi, Bluetooth
# 4  13.3 INCH IPS 2.5K 2560X1600               WiFi + BT4.0, HiRes Webcam
#
#                                            Deskripsi               Warna  \
# 0  - Processor: Intel Core™ I5- 3.70 GHz - Frekue...                Grey
# 1  Travelmate P214 Core-i5 8G 512GB SSD 14 Inch W...                   -
# 2  Travelmate P214, Core-i3, 8G, 512GB SSD, 14 In...                   -
# 3  Notebook Axioo Mybook Pro L5 (8N5), Layar 14 i...                   -
# 4  Spesifikasi : Processor : Intel Celeron N4020 ...  HITAM, BIRU, MERAH
#
#   Negara Asal Pembuatan Produk Label Produk Ramah Lingkungan Hidup  \
# 0                    Indonesia                                   -
# 1                    Indonesia                                   -
# 2                    Indonesia                                   -
# 3                    Indonesia       Produk Ramah Lingkungan Hidup
# 4                    INDONESIA                                   -
#
#                      Keterangan Lainnya
# 0                                     -
# 1  Garansi 2 tahun part & 3 tahun labor
# 2  Garansi 2 tahun part & 3 tahun labor
# 3                       Garansi 1 tahun
# 4                                     -
#
# [5 rows x 36 columns]

# %%
df_norm = df.copy()

# %% [markdown]
# ### General Data

# %%
# derive ID from URL
df_norm["id"] = df_norm["url"].str.extract(r"\/(\d+)\?")

# %%
# derive product name
# df_norm["product_name"] = df_norm["Nama Produk"].str.strip()

# %%
# derive stock
df_norm["stock_parsed"] = df_norm["stock"].str.extract(r"(\d+)").astype(float)

# %%
# derive price
df_norm["price_parsed"] = (
    df_norm["price"]
    .str.replace(".", "")
    .str.replace(",", ".")
    .str.replace("Rp ", "")
    .astype(float)
)

# %%
# derive expiry date
df_norm["expiry_date"] = pd.to_datetime(df_norm["Masa Berlaku Produk"], errors="coerce")

# %%
# derive scores
df_norm["bmp_score"] = df_norm["Nilai BMP"].replace("-", None).astype(float)
df_norm["tkdn_score"] = df_norm["Nilai TKDN(%)"].replace("Tidak Ada", None).astype(float)
df_norm["tkdn_bmp_score"] = df_norm["Nilai TKDN + Nilai BMP"].astype(float)

# %%
# derive unit measurement
df_norm["unit_measurement"] = df_norm["Unit Pengukuran"].str.lower().str.strip()

# %%
# derive codes
df_norm["kbki_code"] = df_norm["Kode KBKI"].str.strip()
df_norm["sni_number"] = df_norm["No. SNI"].str.strip().replace("Tidak Ada", None)

# %%
# derive warnings
df_norm["is_inactive"] = ~df_norm["alerts"].isna()
df_norm["warning_wrong_category"] = df_norm["alerts"].str.contains("Salah Kategori", na=False)
df_norm["warning_wrong_description"] = df_norm["alerts"].str.contains("Ketidaksesuaian Informasi Produk", na=False)

# %% [markdown]
# ### Brand and Company

# %%
# derive brand
df_norm["brand_status"] = df_norm["Status Merek"].replace("-", None)

df_norm["brand_parsed"] = (
    df_norm["Merek"]
    .str.upper()
    .str.replace("(\+|LOGO|PONGO|MYPC|MYBOOK)", "", regex=True)
    .str.replace("LIBERAL", "LIBERA")
    .str.replace("MACBOOK", "APPLE")
    .str.strip()
    .replace("TANPA MEREK", None)
)

# %%
# derive company name
ruleset_company_names = {
    "TERA DATA": ["PT TERA DATA INDONUSA TBK"],
}

df_norm["certificate_holder_company"] = (
    df_norm["Nama Pemilik Merek"]
    .replace("-", None)
    .str.upper()
)

df_norm["brand_holder_company"] = (
    df_norm["Nama Pemilik Merek"]
    .replace("-", None)
    .str.upper()
    .str.replace("PT.", "PT")
    .str.replace("CV.", "CV")
    .apply(string_replace_ruleset(ruleset_company_names))
)

df_norm["provider_product_number"] = df_norm["No. Produk Penyedia"].str.strip()
df_norm["provider_company"] = (
    df_norm["tags"].apply(lambda x: x[0])
    .replace("-", None)
    .str.upper()
    .str.replace("PT.", "PT")
    .str.replace("CV.", "CV")
    .apply(string_replace_ruleset(ruleset_company_names))
)

# %%
# derive manufacturer
ruleset_manufacturer_country = {
    "Indonesia": ["indo", "idn", "pdn", "jakarta", "lokal"],
    "Swiss": ["swiss"],
    "Korea": ["korea"],
    "Taiwan": ["taiwan"],
    "Tiongkok": ["tiongk"],
    "Cina": ["china", "cina"],
    "Jepang": ["jepang", "japan"],
    "Amerika Serikat": ["amerika", "california", "usa"],
    "Lainnya": ["ada", "import", "--", "n/a", "star black", "hitam", "tidak", "."],
}

df_norm["manufacturing_country"] = df_norm["Negara Asal Pembuatan Produk"].apply(
    string_replace_ruleset(ruleset_manufacturer_country)
)

# %% [markdown]
# ### Laptop Specs

# %%
# memory
df_norm["memory"] = df_norm["RAM"].str.extract("(\d+) ?GB", expand=False).astype(float)

# %%
# storage
def derive_storage(x):
    if x is None or pd.isna(x[0]) or pd.isna(x[1]):
        return None
    
    if "T" in x[1]:
        return int(x[0]) * 1024
    
    return int(x[0])

df_norm["storage"] = df_norm["Storage"].str.extract("(\d+) ?(GB?|TB?)", expand=True).apply(derive_storage, axis=1)

# %%
# merge with tags
df_norm = df_norm.merge(df_product_tags, on="id")

# drop raw columns
df_norm = df_norm.drop(columns=[
    "price",
    "stock",
    "tags",
    "details",
    "alerts"
])

# rename columns
df_norm = df_norm.rename(columns={
    # title
    "title": "product_name",

    # original columns
    "Type/Model": "model",
    "Processor": "processor",
    # "RAM": "memory",
    # "Storage": "storage",
    "VGA": "graphics_card",
    "Ukuran Layar": "screen_size",
    "Koneksi": "connectivity",
    "Warna": "color",
    "Deskripsi": "description",
    "Keterangan Lainnya": "extra_description",

    # parsed columns
    "stock_parsed": "stock",
    "price_parsed": "price",
    "brand_parsed": "brand"
})

# %%
# select relevant columns
sel_cols = [
    # general data
    "id", "sku", "product_name", "price", "stock", "unit_measurement",

    # LKPP detail
    "is_inactive", "expiry_date", "bmp_score", "tkdn_score", "tkdn_bmp_score", "kbki_code", "sni_number", 
    "brand", "brand_status", "brand_holder_company", "certificate_holder_company", 
    "provider_company", "provider_product_number", "manufacturing_country",

    # laptop specs
    "model", "processor", "memory", "storage", "graphics_card", "screen_size", "connectivity", "color", 
    
    # extra data
    "warning_wrong_category", "warning_wrong_description", *product_tags_cols,
    "description", "extra_description", "url"
]

# copy and drop duplicates
df_final = df_norm[sel_cols].drop_duplicates(subset=["id"])
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1964 entries, 0 to 3271
# Data columns (total 37 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          1964 non-null   object
#  1   sku                         1964 non-null   object
#  2   product_name                1964 non-null   object
#  3   price                       1964 non-null   float64
#  4   stock                       1894 non-null   float64
#  5   unit_measurement            1964 non-null   object
#  6   is_inactive                 1964 non-null   bool
#  7   expiry_date                 1963 non-null   datetime64[ns]
#  8   bmp_score                   1753 non-null   float64
#  9   tkdn_score                  1933 non-null   float64
#  10  tkdn_bmp_score              1933 non-null   float64
#  11  kbki_code                   1964 non-null   object
#  12  sni_number                  0 non-null      object
#  13  brand                       1539 non-null   object
#  14  brand_status                1539 non-null   object
#  15  brand_holder_company        1539 non-null   object
#  16  certificate_holder_company  1539 non-null   object
#  17  provider_company            1964 non-null   object
#  18  provider_product_number     1964 non-null   object
#  19  manufacturing_country       1590 non-null   object
#  20  model                       1924 non-null   object
#  21  processor                   1934 non-null   object
#  22  memory                      1804 non-null   float64
#  23  storage                     1808 non-null   float64
#  24  graphics_card               1934 non-null   object
#  25  screen_size                 1927 non-null   object
#  26  connectivity                1933 non-null   object
#  27  color                       1942 non-null   object
#  28  warning_wrong_category      1964 non-null   bool
#  29  warning_wrong_description   1964 non-null   bool
#  30  tag_umkk                    1964 non-null   bool
#  31  tag_verified_vendor         1964 non-null   bool
#  32  tag_official_vendor         1964 non-null   bool
#  33  tag_produk_dalam_negeri     1964 non-null   bool
#  34  description                 1932 non-null   object
#  35  extra_description           1412 non-null   object
#  36  url                         1964 non-null   object
# dtypes: bool(7), datetime64[ns](1), float64(7), object(22)
# memory usage: 489.1+ KB

# %%
# save to file
df_final.to_json("../data/clean/lkpp-products.jsonl", orient="records", lines=True)
df_final.head()
# Out:
#          id                       sku  \
# 0  83451581  4522100001-LTN-224654966
# 1  84521755  4522100001-LTN-230428659
# 2  84521452  4522100001-LTN-230427140
# 3  83971989  4522100001-LTN-227419165
# 4  80375727  4522100001-LTN-208199795
#
#                                         product_name       price  stock  \
# 0              LAPTOP ADMINISTRASI PERKANTORAN AXIOO  12500000.0    5.0
# 1  ACER LAPTOP TRAVELMATE P214 CORE I5/8 GB/512 G...  18300000.0  312.0
# 2  ACER LAPTOP TRAVELMATE P214 CORE I3/8 GB/512 G...  15070000.0  312.0
# 3           AXIOO LAPTOP MYBOOK PRO CORE I5 L5 (8N5)  18100000.0  211.0
# 4                            AXIOO LAPTOP MYBOOK 14F   3999000.0    1.0
#
#   unit_measurement  is_inactive expiry_date  bmp_score  tkdn_score  ...  \
# 0             unit         True  2024-12-31        NaN       99.64  ...
# 1             unit        False  2025-12-31        NaN       99.04  ...
# 2             unit        False  2025-12-31        NaN       99.04  ...
# 3             unit         True  2025-12-31        NaN       99.04  ...
# 4             unit         True  2025-12-31        NaN       99.04  ...
#
#                 color warning_wrong_category warning_wrong_description  \
# 0                Grey                   True                      True
# 1                   -                  False                     False
# 2                   -                  False                     False
# 3                   -                  False                      True
# 4  HITAM, BIRU, MERAH                  False                      True
#
#   tag_umkk tag_verified_vendor tag_official_vendor tag_produk_dalam_negeri  \
# 0     True                True               False                    True
# 1     True                True               False                    True
# 2     True                True               False                    True
# 3     True                True               False                    True
# 4     True                True               False                    True
#
#                                          description  \
# 0  - Processor: Intel Core™ I5- 3.70 GHz - Frekue...
# 1  Travelmate P214 Core-i5 8G 512GB SSD 14 Inch W...
# 2  Travelmate P214, Core-i3, 8G, 512GB SSD, 14 In...
# 3  Notebook Axioo Mybook Pro L5 (8N5), Layar 14 i...
# 4  Spesifikasi : Processor : Intel Celeron N4020 ...
#
#                       extra_description  \
# 0                                     -
# 1  Garansi 2 tahun part & 3 tahun labor
# 2  Garansi 2 tahun part & 3 tahun labor
# 3                       Garansi 1 tahun
# 4                                     -
#
#                                                  url
# 0  https://e-katalog.lkpp.go.id/katalog/produk/de...
# 1  https://e-katalog.lkpp.go.id/katalog/produk/de...
# 2  https://e-katalog.lkpp.go.id/katalog/produk/de...
# 3  https://e-katalog.lkpp.go.id/katalog/produk/de...
# 4  https://e-katalog.lkpp.go.id/katalog/produk/de...
#
# [5 rows x 37 columns]
